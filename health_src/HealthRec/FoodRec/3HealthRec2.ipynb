# %%
# seed 2025
# !python runner.py -d baseline_dataset_allrecipe -m CIKM_Model -s 2025
# Out:
# 09 Oct 10:48    INFO ██Server: 	22f6ae151c30
# 09 Oct 10:48    INFO ██Dir: 	/workspace/HealthRec/FoodRec
#
# 09 Oct 10:48    INFO
# gpu_id=5
# use_gpu=True
# seed=[2025]
# data_path=../../../data/jeehoshin/
# log_root=./log/
# ckp_root=./ckp/
# is_multimodal_model=True
# checkpoint_dir=saved
# save_recommended_topk=False
# recommend_topk=recommend_topk/
# embedding_size=64
# weight_decay=0.0
# req_training=True
# epochs=1000
# stopping_step=20
# train_batch_size=2048
# learner=adam
# learning_rate=0.002
# learning_rate_scheduler=[1.0, 50]
# eval_step=1
# metrics=['Recall', 'NDCG']
# topk=[10, 20]
# valid_metric=Recall@20
# eval_batch_size=4096
# eval_by_user=False
# full_sort=False
# end2end=False
# SCHGN_ssl=False
# load_UserRecipe_graph=False
# load_RecipeRecipe_graph=False
# load_RecipeIngre_graph=True
# load_IngreIngre_graph=False
# load_RecipeCalories_graph=False
# load_RecipeHealth_graph=False
# use_cal_level=False
# use_health_level=False
# load_RecipeRecipeCo_graph=False
# ...
