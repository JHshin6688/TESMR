# %%
# seed 999
# !python runner.py -d baseline_dataset_allrecipe -m PRICAI_ModelX
# Out:
# 18 Sep 13:58    INFO ██Server: 	22f6ae151c30
# 18 Sep 13:58    INFO ██Dir: 	/workspace/HealthRec/FoodRec
#
# 18 Sep 13:58    INFO
# gpu_id=4
# use_gpu=True
# seed=[999]
# data_path=../../../data/jeehoshin/
# log_root=./log/
# ckp_root=./ckp/
# is_multimodal_model=True
# checkpoint_dir=saved
# save_recommended_topk=False
# recommend_topk=recommend_topk/
# embedding_size=64
# weight_decay=0.0
# req_training=True
# epochs=1000
# stopping_step=20
# train_batch_size=2048
# learner=adam
# learning_rate=[0.02, 0.002, 0.0002]
# learning_rate_scheduler=[0.5, 50]
# eval_step=1
# metrics=['Recall', 'NDCG']
# topk=[10, 20]
# valid_metric=Recall@20
# eval_batch_size=4096
# eval_by_user=False
# full_sort=False
# end2end=False
# SCHGN_ssl=False
# load_UserRecipe_graph=False
# load_RecipeRecipe_graph=False
# load_RecipeIngre_graph=True
# load_IngreIngre_graph=False
# load_RecipeCalories_graph=False
# load_RecipeHealth_graph=False
# use_cal_level=False
# use_health_level=False
# ...

# %%
# seed 999
# !python runner.py -d baseline_dataset_foodcom -m PRICAI_ModelX
# Out:
# 30 Sep 23:47    INFO ██Server: 	22f6ae151c30
# 30 Sep 23:47    INFO ██Dir: 	/workspace/HealthRec/FoodRec
#
# 30 Sep 23:47    INFO
# gpu_id=7
# use_gpu=True
# seed=[999]
# data_path=../../../data/jeehoshin/
# log_root=./log/
# ckp_root=./ckp/
# is_multimodal_model=True
# checkpoint_dir=saved
# save_recommended_topk=False
# recommend_topk=recommend_topk/
# embedding_size=64
# weight_decay=0.0
# req_training=True
# epochs=1000
# stopping_step=20
# train_batch_size=2048
# learner=adam
# learning_rate=[0.01, 0.001, 0.0001]
# learning_rate_scheduler=[0.5, 50]
# eval_step=1
# metrics=['Recall', 'NDCG']
# topk=[10, 20]
# valid_metric=Recall@20
# eval_batch_size=4096
# eval_by_user=False
# full_sort=False
# end2end=False
# SCHGN_ssl=False
# load_UserRecipe_graph=False
# load_RecipeRecipe_graph=False
# load_RecipeIngre_graph=True
# load_IngreIngre_graph=False
# load_RecipeCalories_graph=False
# load_RecipeHealth_graph=False
# use_cal_level=False
# use_health_level=False
# ...

# %%
# seed 42
# !python runner.py -d baseline_dataset_foodcom -m PRICAI_ModelX -s 42
# Out:
# 05 Oct 06:32    INFO ██Server: 	22f6ae151c30
# 05 Oct 06:32    INFO ██Dir: 	/workspace/HealthRec/FoodRec
#
# 05 Oct 06:32    INFO
# gpu_id=6
# use_gpu=True
# seed=[42]
# data_path=../../../data/jeehoshin/
# log_root=./log/
# ckp_root=./ckp/
# is_multimodal_model=True
# checkpoint_dir=saved
# save_recommended_topk=False
# recommend_topk=recommend_topk/
# embedding_size=64
# weight_decay=0.0
# req_training=True
# epochs=1000
# stopping_step=20
# train_batch_size=2048
# learner=adam
# learning_rate=[0.001]
# learning_rate_scheduler=[0.5, 50]
# eval_step=1
# metrics=['Recall', 'NDCG']
# topk=[10, 20]
# valid_metric=Recall@20
# eval_batch_size=4096
# eval_by_user=False
# full_sort=False
# end2end=False
# SCHGN_ssl=False
# load_UserRecipe_graph=False
# load_RecipeRecipe_graph=False
# load_RecipeIngre_graph=True
# load_IngreIngre_graph=False
# load_RecipeCalories_graph=False
# load_RecipeHealth_graph=False
# use_cal_level=False
# use_health_level=False
# load_RecipeRecipeCo_graph=False
# ...

# %%
# seed 123
# !python runner.py -d baseline_dataset_foodcom -m PRICAI_ModelX -s 123
# Out:
# 05 Oct 08:30    INFO ██Server: 	22f6ae151c30
# 05 Oct 08:30    INFO ██Dir: 	/workspace/HealthRec/FoodRec
#
# 05 Oct 08:30    INFO
# gpu_id=6
# use_gpu=True
# seed=[123]
# data_path=../../../data/jeehoshin/
# log_root=./log/
# ckp_root=./ckp/
# is_multimodal_model=True
# checkpoint_dir=saved
# save_recommended_topk=False
# recommend_topk=recommend_topk/
# embedding_size=64
# weight_decay=0.0
# req_training=True
# epochs=1000
# stopping_step=20
# train_batch_size=2048
# learner=adam
# learning_rate=[0.001]
# learning_rate_scheduler=[0.5, 50]
# eval_step=1
# metrics=['Recall', 'NDCG']
# topk=[10, 20]
# valid_metric=Recall@20
# eval_batch_size=4096
# eval_by_user=False
# full_sort=False
# end2end=False
# SCHGN_ssl=False
# load_UserRecipe_graph=False
# load_RecipeRecipe_graph=False
# load_RecipeIngre_graph=True
# load_IngreIngre_graph=False
# load_RecipeCalories_graph=False
# load_RecipeHealth_graph=False
# use_cal_level=False
# use_health_level=False
# load_RecipeRecipeCo_graph=False
# ...

# %%
# seed 2025
# !python runner.py -d baseline_dataset_foodcom -m PRICAI_ModelX -s 2025
# Out:
# 05 Oct 10:34    INFO ██Server: 	22f6ae151c30
# 05 Oct 10:34    INFO ██Dir: 	/workspace/HealthRec/FoodRec
#
# 05 Oct 10:34    INFO
# gpu_id=6
# use_gpu=True
# seed=[2025]
# data_path=../../../data/jeehoshin/
# log_root=./log/
# ckp_root=./ckp/
# is_multimodal_model=True
# checkpoint_dir=saved
# save_recommended_topk=False
# recommend_topk=recommend_topk/
# embedding_size=64
# weight_decay=0.0
# req_training=True
# epochs=1000
# stopping_step=20
# train_batch_size=2048
# learner=adam
# learning_rate=[0.001]
# learning_rate_scheduler=[0.5, 50]
# eval_step=1
# metrics=['Recall', 'NDCG']
# topk=[10, 20]
# valid_metric=Recall@20
# eval_batch_size=4096
# eval_by_user=False
# full_sort=False
# end2end=False
# SCHGN_ssl=False
# load_UserRecipe_graph=False
# load_RecipeRecipe_graph=False
# load_RecipeIngre_graph=True
# load_IngreIngre_graph=False
# load_RecipeCalories_graph=False
# load_RecipeHealth_graph=False
# use_cal_level=False
# use_health_level=False
# load_RecipeRecipeCo_graph=False
# ...

# %%
# seed 54321
# !python runner.py -d baseline_dataset_foodcom -m PRICAI_ModelX -s 54321
# Out:
# 05 Oct 12:58    INFO ██Server: 	22f6ae151c30
# 05 Oct 12:58    INFO ██Dir: 	/workspace/HealthRec/FoodRec
#
# 05 Oct 12:58    INFO
# gpu_id=6
# use_gpu=True
# seed=[54321]
# data_path=../../../data/jeehoshin/
# log_root=./log/
# ckp_root=./ckp/
# is_multimodal_model=True
# checkpoint_dir=saved
# save_recommended_topk=False
# recommend_topk=recommend_topk/
# embedding_size=64
# weight_decay=0.0
# req_training=True
# epochs=1000
# stopping_step=20
# train_batch_size=2048
# learner=adam
# learning_rate=[0.001]
# learning_rate_scheduler=[0.5, 50]
# eval_step=1
# metrics=['Recall', 'NDCG']
# topk=[10, 20]
# valid_metric=Recall@20
# eval_batch_size=4096
# eval_by_user=False
# full_sort=False
# end2end=False
# SCHGN_ssl=False
# load_UserRecipe_graph=False
# load_RecipeRecipe_graph=False
# load_RecipeIngre_graph=True
# load_IngreIngre_graph=False
# load_RecipeCalories_graph=False
# load_RecipeHealth_graph=False
# use_cal_level=False
# use_health_level=False
# load_RecipeRecipeCo_graph=False
# ...

# %%
# hyperparameter 설정 바꾸고 돌리기
# seed 42
# !python runner.py -d baseline_dataset_allrecipe -m PRICAI_ModelX -s 42
# Out:
# 06 Oct 11:34    INFO ██Server: 	22f6ae151c30
# 06 Oct 11:34    INFO ██Dir: 	/workspace/HealthRec/FoodRec
#
# 06 Oct 11:34    INFO
# gpu_id=7
# use_gpu=True
# seed=[42]
# data_path=../../../data/jeehoshin/
# log_root=./log/
# ckp_root=./ckp/
# is_multimodal_model=True
# checkpoint_dir=saved
# save_recommended_topk=False
# recommend_topk=recommend_topk/
# embedding_size=64
# weight_decay=0.0
# req_training=True
# epochs=1000
# stopping_step=20
# train_batch_size=2048
# learner=adam
# learning_rate=[0.002]
# learning_rate_scheduler=[0.5, 50]
# eval_step=1
# metrics=['Recall', 'NDCG']
# topk=[10, 20]
# valid_metric=Recall@20
# eval_batch_size=4096
# eval_by_user=False
# full_sort=False
# end2end=False
# SCHGN_ssl=False
# load_UserRecipe_graph=False
# load_RecipeRecipe_graph=False
# load_RecipeIngre_graph=True
# load_IngreIngre_graph=False
# load_RecipeCalories_graph=False
# load_RecipeHealth_graph=False
# use_cal_level=False
# use_health_level=False
# load_RecipeRecipeCo_graph=False
# ...

# %%
# seed 123
# !python runner.py -d baseline_dataset_allrecipe -m PRICAI_ModelX -s 123
# Out:
# 06 Oct 19:26    INFO ██Server: 	22f6ae151c30
# 06 Oct 19:26    INFO ██Dir: 	/workspace/HealthRec/FoodRec
#
# 06 Oct 19:26    INFO
# gpu_id=7
# use_gpu=True
# seed=[123]
# data_path=../../../data/jeehoshin/
# log_root=./log/
# ckp_root=./ckp/
# is_multimodal_model=True
# checkpoint_dir=saved
# save_recommended_topk=False
# recommend_topk=recommend_topk/
# embedding_size=64
# weight_decay=0.0
# req_training=True
# epochs=1000
# stopping_step=20
# train_batch_size=2048
# learner=adam
# learning_rate=[0.002]
# learning_rate_scheduler=[0.5, 50]
# eval_step=1
# metrics=['Recall', 'NDCG']
# topk=[10, 20]
# valid_metric=Recall@20
# eval_batch_size=4096
# eval_by_user=False
# full_sort=False
# end2end=False
# SCHGN_ssl=False
# load_UserRecipe_graph=False
# load_RecipeRecipe_graph=False
# load_RecipeIngre_graph=True
# load_IngreIngre_graph=False
# load_RecipeCalories_graph=False
# load_RecipeHealth_graph=False
# use_cal_level=False
# use_health_level=False
# load_RecipeRecipeCo_graph=False
# ...

# %%
# seed 2025
# !python runner.py -d baseline_dataset_allrecipe -m PRICAI_ModelX -s 2025
# Out:
# 07 Oct 03:15    INFO ██Server: 	22f6ae151c30
# 07 Oct 03:15    INFO ██Dir: 	/workspace/HealthRec/FoodRec
#
# 07 Oct 03:15    INFO
# gpu_id=7
# use_gpu=True
# seed=[2025]
# data_path=../../../data/jeehoshin/
# log_root=./log/
# ckp_root=./ckp/
# is_multimodal_model=True
# checkpoint_dir=saved
# save_recommended_topk=False
# recommend_topk=recommend_topk/
# embedding_size=64
# weight_decay=0.0
# req_training=True
# epochs=1000
# stopping_step=20
# train_batch_size=2048
# learner=adam
# learning_rate=[0.002]
# learning_rate_scheduler=[0.5, 50]
# eval_step=1
# metrics=['Recall', 'NDCG']
# topk=[10, 20]
# valid_metric=Recall@20
# eval_batch_size=4096
# eval_by_user=False
# full_sort=False
# end2end=False
# SCHGN_ssl=False
# load_UserRecipe_graph=False
# load_RecipeRecipe_graph=False
# load_RecipeIngre_graph=True
# load_IngreIngre_graph=False
# load_RecipeCalories_graph=False
# load_RecipeHealth_graph=False
# use_cal_level=False
# use_health_level=False
# load_RecipeRecipeCo_graph=False
# ...

# %%
# seed 54321
# !python runner.py -d baseline_dataset_allrecipe -m PRICAI_ModelX -s 54321
# Out:
# 07 Oct 10:20    INFO ██Server: 	22f6ae151c30
# 07 Oct 10:20    INFO ██Dir: 	/workspace/HealthRec/FoodRec
#
# 07 Oct 10:20    INFO
# gpu_id=7
# use_gpu=True
# seed=[54321]
# data_path=../../../data/jeehoshin/
# log_root=./log/
# ckp_root=./ckp/
# is_multimodal_model=True
# checkpoint_dir=saved
# save_recommended_topk=False
# recommend_topk=recommend_topk/
# embedding_size=64
# weight_decay=0.0
# req_training=True
# epochs=1000
# stopping_step=20
# train_batch_size=2048
# learner=adam
# learning_rate=[0.002]
# learning_rate_scheduler=[0.5, 50]
# eval_step=1
# metrics=['Recall', 'NDCG']
# topk=[10, 20]
# valid_metric=Recall@20
# eval_batch_size=4096
# eval_by_user=False
# full_sort=False
# end2end=False
# SCHGN_ssl=False
# load_UserRecipe_graph=False
# load_RecipeRecipe_graph=False
# load_RecipeIngre_graph=True
# load_IngreIngre_graph=False
# load_RecipeCalories_graph=False
# load_RecipeHealth_graph=False
# use_cal_level=False
# use_health_level=False
# load_RecipeRecipeCo_graph=False
# ...
