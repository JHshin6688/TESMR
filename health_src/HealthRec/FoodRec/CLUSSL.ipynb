# %%
# using best hyperparameter from the paper

# overall
# stopping_step: 5
# eval_batch_size: 256

# cikm
# epochs: 50
# loss_kd: 0.05 -> loss_kd: [0.01, 0.05, 0.1]
# loss_health: 0.1 -> loss_health: [0.05, 0.1, 0.5]
# learning_rate: 0.002 -> learning_rate: [0.02, 0.002, 0.0002]
# train_batch_size: 512
# learning_rate_scheduler: [0.5, 50]

# !python runner.py -m CIKM_Model
# Out:
# 05 Sep 11:49    INFO ██Server: 	22f6ae151c30
# 05 Sep 11:49    INFO ██Dir: 	/workspace/HealthRec/FoodRec
#
# 05 Sep 11:49    INFO
# gpu_id=3
# use_gpu=True
# seed=[999]
# data_path=../../../data/jeehoshin/healthrec_dataset/
# log_root=./log/
# ckp_root=./ckp/
# is_multimodal_model=True
# checkpoint_dir=saved
# save_recommended_topk=False
# recommend_topk=recommend_topk/
# embedding_size=64
# weight_decay=0.0
# req_training=True
# epochs=50
# stopping_step=5
# learning_rate_scheduler=[0.5, 50]
# eval_step=1
# test_step=5
# learner=adam
# learning_rate=[0.02, 0.002, 0.0002]
# metrics=['Recall', 'NDCG']
# topk=[10, 20]
# valid_metric=Recall@20
# eval_batch_size=256
# eval_by_user=False
# full_sort=True
# end2end=False
# SCHGN_ssl=False
# load_UserRecipe_graph=False
# load_RecipeRecipe_graph=False
# load_RecipeIngre_graph=True
# load_IngreIngre_graph=False
# load_RecipeCalories_graph=False
# load_RecipeHealth_graph=False
# use_cal_level=False
# use_health_level=False
# ...

# %%
# 데이터셋 mapping 수정 + hyperparameter 세팅 MMRec과 통일 + 평가 방식 수정
# !python runner.py -d baseline_dataset_allrecipe -m PRICAI_ModelX
# Out:
# 15 Sep 14:50    INFO ██Server: 	22f6ae151c30
# 15 Sep 14:50    INFO ██Dir: 	/workspace/HealthRec/FoodRec
#
# 15 Sep 14:50    INFO
# gpu_id=4
# use_gpu=True
# seed=[999]
# data_path=../../../data/jeehoshin/
# log_root=./log/
# ckp_root=./ckp/
# is_multimodal_model=True
# checkpoint_dir=saved
# save_recommended_topk=False
# recommend_topk=recommend_topk/
# embedding_size=64
# weight_decay=0.0
# req_training=True
# epochs=1000
# stopping_step=20
# train_batch_size=2048
# learner=adam
# learning_rate=[0.02, 0.002, 0.0002]
# learning_rate_scheduler=[0.5, 50]
# eval_step=1
# metrics=['Recall', 'NDCG']
# topk=[10, 20]
# valid_metric=Recall@20
# eval_batch_size=4096
# eval_by_user=False
# full_sort=False
# end2end=False
# SCHGN_ssl=False
# load_UserRecipe_graph=False
# load_RecipeRecipe_graph=False
# load_RecipeIngre_graph=True
# load_IngreIngre_graph=False
# load_RecipeCalories_graph=False
# load_RecipeHealth_graph=False
# use_cal_level=False
# use_health_level=False
# ...

# %%
# 데이터셋 mapping 수정 + hyperparameter 세팅 MMRec과 통일 + 평가 방식 수정
# training dataset masking 추가
# !python runner.py -d baseline_dataset_allrecipe -m PRICAI_ModelX
# Out:
# 18 Sep 13:58    INFO ██Server: 	22f6ae151c30
# 18 Sep 13:58    INFO ██Dir: 	/workspace/HealthRec/FoodRec
#
# 18 Sep 13:58    INFO
# gpu_id=4
# use_gpu=True
# seed=[999]
# data_path=../../../data/jeehoshin/
# log_root=./log/
# ckp_root=./ckp/
# is_multimodal_model=True
# checkpoint_dir=saved
# save_recommended_topk=False
# recommend_topk=recommend_topk/
# embedding_size=64
# weight_decay=0.0
# req_training=True
# epochs=1000
# stopping_step=20
# train_batch_size=2048
# learner=adam
# learning_rate=[0.02, 0.002, 0.0002]
# learning_rate_scheduler=[0.5, 50]
# eval_step=1
# metrics=['Recall', 'NDCG']
# topk=[10, 20]
# valid_metric=Recall@20
# eval_batch_size=4096
# eval_by_user=False
# full_sort=False
# end2end=False
# SCHGN_ssl=False
# load_UserRecipe_graph=False
# load_RecipeRecipe_graph=False
# load_RecipeIngre_graph=True
# load_IngreIngre_graph=False
# load_RecipeCalories_graph=False
# load_RecipeHealth_graph=False
# use_cal_level=False
# use_health_level=False
# ...

# %%
# hyperparameter 세팅 MMRec과 통일 + 평가 방식 수정
# training dataset masking 추가
# !python runner.py -d baseline_dataset_foodcom -m PRICAI_ModelX
# Out:
# 30 Sep 23:47    INFO ██Server: 	22f6ae151c30
# 30 Sep 23:47    INFO ██Dir: 	/workspace/HealthRec/FoodRec
#
# 30 Sep 23:47    INFO
# gpu_id=7
# use_gpu=True
# seed=[999]
# data_path=../../../data/jeehoshin/
# log_root=./log/
# ckp_root=./ckp/
# is_multimodal_model=True
# checkpoint_dir=saved
# save_recommended_topk=False
# recommend_topk=recommend_topk/
# embedding_size=64
# weight_decay=0.0
# req_training=True
# epochs=1000
# stopping_step=20
# train_batch_size=2048
# learner=adam
# learning_rate=[0.01, 0.001, 0.0001]
# learning_rate_scheduler=[0.5, 50]
# eval_step=1
# metrics=['Recall', 'NDCG']
# topk=[10, 20]
# valid_metric=Recall@20
# eval_batch_size=4096
# eval_by_user=False
# full_sort=False
# end2end=False
# SCHGN_ssl=False
# load_UserRecipe_graph=False
# load_RecipeRecipe_graph=False
# load_RecipeIngre_graph=True
# load_IngreIngre_graph=False
# load_RecipeCalories_graph=False
# load_RecipeHealth_graph=False
# use_cal_level=False
# use_health_level=False
# ...
