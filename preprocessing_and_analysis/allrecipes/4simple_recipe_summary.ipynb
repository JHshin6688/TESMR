# %%
import os
os.environ['CUDA_DEVICE_ORDER']="PCI_BUS_ID"
os.environ['CUDA_VISIBLE_DEVICES']='6'

import torch

print(torch.__version__)
print(torch.version.cuda)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

print(torch.cuda.is_available())
print(torch.cuda.current_device())
print(torch.cuda.get_device_name)
# Out:
# 2.1.0
# 11.8
# cuda
# True
# 0
# <function get_device_name at 0x7f6c04810a60>

# %%
import pandas as pd
import ast
from tqdm import tqdm
from PIL import Image
from transformers import AutoProcessor, LlavaForConditionalGeneration

data_path = "../../data/jeehoshin/allrecipe_dataset/"
recipes = pd.read_csv(data_path + "core-data_recipe.csv")

# Preprocess nutrition data (Use 7 major nutritions and format it as a string)
for i in range(len(recipes)):
    nutri = recipes.iloc[i]['nutritions']
    nutri_dict = ast.literal_eval(nutri)

    selected_keys = ['sugars', 'sodium', 'carbohydrates', 'calories', 'fat', 'saturatedFat', 'fiber']
    filtered_nutri = {key: nutri_dict[key] for key in selected_keys if key in nutri_dict}

    nutrition_summary = ""
    for key in selected_keys:
        value = filtered_nutri.get(key, {})
        amount = value.get('displayValue', 0)
        unit = value.get('unit', '')
        nutrition_summary += f"{key}: {amount}{unit}, "
    
    recipes.at[i, 'nutrition_summary'] = nutrition_summary

recipes.drop(columns=['cooking_directions', 'nutritions'], inplace=True)

recipes.to_csv(data_path + "core-data_recipe_processed.csv", index=False)
print("nutrition data processing completed")
# Out:
# nutrition data processing completed

# %%
import re

cache_dir = "../../data/jeehoshin/huggingface"
model_id = "llava-hf/llava-1.5-7b-hf"
model = LlavaForConditionalGeneration.from_pretrained(
    model_id, 
    cache_dir=cache_dir,
    torch_dtype=torch.float16, 
    low_cpu_mem_usage=True, 
).to(0)

processor = AutoProcessor.from_pretrained(
    model_id,
    cache_dir=cache_dir
)

def extract_summary_with_tags(generated_text):
    matches = re.search(r"<summary>(.*)", generated_text, re.DOTALL | re.IGNORECASE)
    if matches:
        return matches.group(1).strip()
    else:
        return generated_text.strip()  # fallback

def generate_batch_summary(model, processor, data_batch, device):
    images, prompts = [], []

    for recipe_id, recipe_name, ingredients, nutritions in data_batch:
        image_path = data_path + f"core-data-images/core-data-images/{recipe_id}.jpg"
        
        try:
            image = Image.open(image_path).convert("RGB")  # Load local image
        except Exception as e:
            print(f"Failed to load image: {image_path}")
            image = Image.new("RGB", (224, 224), (255, 255, 255))  # fallback blank image
        
        images.append(image)

        prompt = f"""
You are a culinary expert. Given the image and the textual information below, write a simple and concise summary of the recipe. 
Your summary should combine key visual characteristics (e.g., color, shape, texture) with notable textual details (e.g., main ingredients and nutritional traits).

Name: {recipe_name}  
Ingredients: {ingredients}  
Nutrition: {nutritions}

<summary>"""

        prompts.append(prompt)
  
    inputs = processor(text = prompts, images = images, return_tensors="pt", padding=True).to(device)
    with torch.no_grad():
        output = model.generate(**inputs, max_new_tokens=200)
    decoded = processor.batch_decode(output, skip_special_tokens=True)
    
    summaries = [extract_summary_with_tags(txt) for txt in decoded]

    return summaries

# Example usage
batch_size = 8
results = []
for i in tqdm(range(0, len(recipes), batch_size)):  
    batch = recipes.iloc[i:i+batch_size][['recipe_id', 'recipe_name', 'ingredients', 'nutrition_summary']].values.tolist()
    batch_results = generate_batch_summary(model, processor, batch, device=torch.device("cuda"))

    results.extend(batch_results)

recipes['summary'] = results

recipes.drop(columns=['image_url', 'ingredients', 'nutrition_summary'], inplace=True)

recipes.to_csv(data_path + "short_recipe_summaries.csv", index=False)

print("Summaries generated and saved.")
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# 100%|█████████████████████████████████████████████████████████████████████| 5704/5704 [12:40:32<00:00,  8.00s/it]
# Summaries generated and saved.

# %%
import pandas as pd
summaries = pd.read_csv(data_path + "short_recipe_summaries.csv")

for i in range(20):
    print(f"Recipe id : {summaries.iloc[i]['recipe_id']}")
    print(f"Recipe name : {summaries.iloc[i]['recipe_name']}")
    print(f"Recipe summary : {summaries.iloc[i]['summary']}")
    print()

# check invalid summaries
count = summaries['summary'].isna().sum()
print(f"# of invalid summaries : {count}")
# Out:
# Recipe id : 240488
# Recipe name : Pork Loin, Apples, and Sauerkraut
# Recipe summary : A pork loin roast is seasoned with Thai seasoning, salt, garlic powder, and ground black pepper. It is then cooked with sauerkraut and sliced Granny Smith apples. The dish is served with apple cider and brown sugar. The nutritional value of the dish includes a moderate amount of sugar, sodium, and calories, with a good amount of fiber.
#
# Recipe id : 218939
# Recipe name : Foolproof Rosemary Chicken Wings
# Recipe summary : The Foolproof Rosemary Chicken Wings recipe involves marinating chicken wings in a mixture of rosemary sprigs, garlic, olive oil, lemon pepper, and seasoned salt. The dish is cooked in the oven, resulting in a flavorful and tender meal. The wings are golden brown and have a slightly crispy texture, with a hint of rosemary and garlic flavor. The nutritional value of this dish is relatively low in calories and fat, making it a healthy option for those looking for a delicious and satisfying meal.
#
# Recipe id : 87211
# Recipe name : Chicken Pesto Paninis
# Recipe summary : A delicious and nutritious sandwich made with focaccia bread, pesto, chicken, green bell pepper, red onion, and Monterey Jack cheese. The sandwich is served with a side of chickpeas, providing a balance of flavors and textures. The sandwich is high in protein, fiber, and healthy fats, making it a satisfying and nutritious meal option.
#
# Recipe id : 245714
# Recipe name : Potato Bacon Pizza
# Recipe summary : A delicious and hearty pizza made with potatoes, bacon, and a rich sauce. The crust is made with warm water, honey, and active dry yeast, and topped with shredded mozzarella cheese. The pizza is high in calories and fat, but also provides some fiber and protein from the potatoes and bacon.
#
# Recipe id : 218545
# Recipe name : Latin-Inspired Spicy Cream Chicken Stew
# Recipe summary : A Latin-inspired spicy cream chicken stew is made with chicken, tomatoes, black beans, pinto beans, corn, taco seasoning, cilantro, red chile pepper, cumin, and cream cheese. The dish is rich in flavor and nutrition, with a mix of protein, carbohydrates, and healthy fats.
#
# Recipe id : 20453
# Recipe name : Reuben Sandwich I
# Recipe summary : A Reuben sandwich is a delicious and hearty meal, consisting of corned beef, sauerkraut, and melted cheese on a toasted rye bread. The sandwich is high in calories, fat, and sodium, but also provides a good amount of fiber and carbohydrates. The combination of flavors and textures makes it a satisfying and indulgent treat.
#
# Recipe id : 244856
# Recipe name : Turkey Black Bean Burgers
# Recipe summary : Turkey Black Bean Burgers are a delicious and nutritious meal option. The burger is made with extra lean ground turkey, cooked black beans, chopped onion, chopped tomato, and fresh parsley. The egg white adds a creamy texture, while the garlic and dried oregano provide a burst of flavor. The burger is seasoned with sea salt and ground black pepper to taste. This meal is low in sugar, high in fiber, and packed with protein, making it a healthy and satisfying choice.
#
# Recipe id : 22402
# Recipe name : Cranberry Pork Chops II
# Recipe summary : Cranberry Pork Chops II is a dish made with pork chops, white sugar, salt, and ground black pepper. The dish is cooked in water as needed. The ingredients are simple and easy to find, and the nutritional traits include a moderate amount of sugar, sodium, and calories, with a relatively low amount of fat and saturated fat. The dish is visually appealing with a combination of red and white colors from the cranberry sauce and the pork chops. The taste is likely to be savory and slightly sweet from the cranberry sauce. Overall, this dish is a delicious and hearty meal option.
#
# Recipe id : 258163
# Recipe name : Schnitzel Sandwich
# Recipe summary : A Schnitzel Sandwich is a delicious and hearty meal, featuring chicken breasts as the main ingredient. The chicken is seasoned with salt, pepper, and flour, then breaded and fried until golden brown. The sandwich is assembled with a split roll, mayonnaise, lemon juice, and hot pepper sauce (optional). The sandwich is garnished with chopped romaine lettuce and mustard. This sandwich is high in calories, fat, and carbohydrates, making it a satisfying meal.
#
# Recipe id : 23658
# Recipe name : Pam's Bierocks
# Recipe summary : Pam's Bierocks are a delicious and hearty meal, made with a combination of lean ground beef, chopped onion, shredded cabbage, and melted butter. The dough is soft and fluffy, with a hint of sweetness from the white sugar. The beef provides a savory flavor, while the onion and cabbage add a touch of freshness and crunch. The dish is served with a side of warm water, which is used to activate the yeast and create a soft, airy texture in the bread. This recipe is a great option for those looking for a satisfying and comforting meal.
#
# Recipe id : 244786
# Recipe name : Zucchini Noodles and Summer Vegetables with Sweet Pepper Chicken Sausage
# Recipe summary : A colorful and nutritious dish featuring zucchini noodles, summer vegetables, and sweet pepper chicken sausages. The dish is seasoned with extra-virgin olive oil, sea salt, and freshly ground black pepper, and garnished with Parmesan cheese and basil. The combination of ingredients provides a balance of flavors and textures, making it a delicious and healthy meal option.
#
# Recipe id : 260453
# Recipe name : Fresh Balsamic Chicken Salad
# Recipe summary : A fresh balsamic chicken salad is made with thinly sliced English cucumbers, halved grape tomatoes, and cooked chicken breast. The salad is dressed with balsamic vinegar, olive oil, salt, and ground black pepper. The dish is low in calories and fat, with a good amount of fiber and vitamins from the vegetables.
#
# Recipe id : 103305
# Recipe name : Hearty Chili
# Recipe summary : A hearty chili recipe made with ground beef, chopped onions, garlic cloves, tomatoes, tomato sauce, Holland House® Red Cooking Wine, chili powder, cumin, green bell pepper, and kidney beans. The dish is rich in flavor and nutrition, with a balance of protein, carbohydrates, and fiber.
#
# Recipe id : 26668
# Recipe name : Tater Tot Casserole III
# Recipe summary : A hearty and flavorful dish, Tater Tot Casserole III combines ground beef, condensed cream of mushroom soup, skim milk, garlic salt, and French style green beans with tater tots. The dish is rich in flavor and nutrition, with a balance of protein, carbohydrates, and healthy fats. The vibrant colors and textures of the ingredients create a visually appealing and appetizing meal.
#
# Recipe id : 185816
# Recipe name : Sweet Pork for Burritos
# Recipe summary : A delicious and hearty burrito recipe made with pork shoulder roast, salsa, and various seasonings. The pork is cooked until tender and then combined with the salsa and seasonings to create a flavorful and satisfying meal. The nutritional value of this dish includes a good amount of protein, carbohydrates, and fiber, making it a filling and nutritious option.
#
# Recipe id : 79814
# Recipe name : Slow Cooker Veggie-Beef Soup with Okra
# Recipe summary : A hearty and flavorful soup made with a combination of ground beef, onions, diced tomatoes, Italian diced tomatoes, frozen mixed vegetables, sliced fresh okra, potatoes, ketchup, salt, and pepper. The soup is rich in nutrients, including carbohydrates, fiber, and a good amount of protein. The colorful ingredients and the slow cooker method create a delicious and comforting meal.
#
# Recipe id : 25507
# Recipe name : Mock Sliders
# Recipe summary : Mock Sliders are a delicious and easy-to-make meal. They consist of corned beef, sour cream, and an envelope dry onion soup mix, all combined with dinner rolls and dill pickle slices drained. The dish is low in calories and fat, making it a healthy and satisfying option for a meal.
#
# Recipe id : 238886
# Recipe name : Midnight Snack Avocado Sandwich
# Recipe summary : The Midnight Snack Avocado Sandwich is a delicious and nutritious meal, featuring a combination of ingredients such as bacon, green onions, mayonnaise, wheat bread, avocado mashed, tomato, alfalfa sprouts, and salt and ground black pepper to taste. The sandwich is topped with a generous amount of avocado, which adds a creamy texture and a rich, healthy fat content. The sandwich is served on a toasted wheat bread, which adds a crispy texture and a slightly sweet flavor. The combination of these ingredients results in a satisfying and nutritious meal, packed with protein, healthy fats, and essential vitamins and minerals.
#
# Recipe id : 235633
# Recipe name : Red Wine Braised Short Ribs with Rosemary
# Recipe summary : The dish is a red wine braised short ribs with rosemary. The ribs are seasoned with salt, black pepper, flour, and rosemary leaves. The dish is cooked in a liquid made from tomato paste, carrots, celery, and garlic. The sauce is made from dry red wine and Swanson® Beef Stock. The dish is served with a side of mashed potatoes.
#
# Recipe id : 50908
# Recipe name : Nanny's Goulash
# Recipe summary : Nanny's Goulash is a hearty and flavorful dish made with lean ground beef, mushrooms, green and red bell peppers, zucchini, small red onions, olives, paprika, dried basil, garlic salt, and peeled tomatoes. The dish is cooked in olive oil and seasoned with white pepper and peeled tomatoes. The nutritional value of the dish is relatively low in calories and fat, but high in fiber and nutrients.
#
# # of invalid summaries : 0
